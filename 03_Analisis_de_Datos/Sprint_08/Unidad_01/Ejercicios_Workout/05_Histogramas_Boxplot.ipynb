# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Visualización con Matplotlib: Histogramas y diagramas de caja

# %% [markdown]
# Vamos a ver de forma sencilla como hacer los gráficos que nos generaban las funciones que empleamos en las visualizaciones analiticas del sprint anteior. En concreto, veremos los histogramas y los boxplots:

# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

data= np.random.randn(1000)

# %% [markdown]
# ### Histogramas

# %% [markdown]
# Tan sencillo como:

# %%
plt.hist(data);

# %%
fig = plt.figure(figsize=(5,4))
ax = plt.axes()
ax.hist(data);

# %% [markdown]
# La función ``hist()`` tiene muchas opciones para ajustar tanto el cálculo como la visualización; aquí tienes un ejemplo de un histograma más personalizado (en el que tocamos el número de columnas `bins`, la transparencia y el color):

# %%
plt.hist(data,
    bins = 50,
    alpha = 0.7,
    color = "steelblue")
# Out:
# (array([ 2.,  1.,  1.,  5.,  1.,  0.,  4.,  5.,  5.,  4.,  8., 18., 21.,
#         26., 18., 20., 18., 29., 44., 39., 30., 53., 36., 43., 56., 63.,
#         48., 40., 35., 33., 42., 36., 34., 30., 33., 19., 11., 15., 18.,
#          8.,  6.,  4.,  9.,  8.,  5.,  3.,  4.,  4.,  3.,  2.]),
#  array([-2.91543408, -2.80051531, -2.68559655, -2.57067778, -2.45575902,
#         -2.34084025, -2.22592149, -2.11100272, -1.99608395, -1.88116519,
#         -1.76624642, -1.65132766, -1.53640889, -1.42149013, -1.30657136,
#         -1.1916526 , -1.07673383, -0.96181507, -0.8468963 , -0.73197753,
#         -0.61705877, -0.50214   , -0.38722124, -0.27230247, -0.15738371,
#         -0.04246494,  0.07245382,  0.18737259,  0.30229135,  0.41721012,
#          0.53212888,  0.64704765,  0.76196642,  0.87688518,  0.99180395,
#          1.10672271,  1.22164148,  1.33656024,  1.45147901,  1.56639777,
#          1.68131654,  1.7962353 ,  1.91115407,  2.02607284,  2.1409916 ,
#          2.25591037,  2.37082913,  2.4857479 ,  2.60066666,  2.71558543,
#          2.83050419]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# La transparencia es particularmente interesante para comparar histogramas o mostrar dicha comparación (y aprovecho para enseñarte un truco para cuando tengas argumentos repetidos que poner en tus llamadas a función):

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(alpha = 0.3, bins = 20)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([  3.,   1.,   3.,   9.,  18.,  42.,  51.,  62.,  86.,  99., 129.,
#         147.,  88.,  98.,  66.,  41.,  32.,  13.,   8.,   4.]),
#  array([-3.83325207, -3.20954054, -2.585829  , -1.96211747, -1.33840593,
#         -0.71469439, -0.09098286,  0.53272868,  1.15644021,  1.78015175,
#          2.40386328,  3.02757482,  3.65128635,  4.27499789,  4.89870942,
#          5.52242096,  6.1461325 ,  6.76984403,  7.39355557,  8.0172671 ,
#          8.64097864]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# Es también el momento de enseñarte a capturar los límites de esos bines:

# %%
fig = plt.Figure()
ax = plt.axes()
limites = ax.hist(x1, alpha = 0.3, bins = 30)

# %% [markdown]
# Limites es una tupla en la que el primer valor son los conteos y el segundo los límites de las barras:

# %%
limites[0]
# Out:
# array([ 1.,  1.,  2.,  4.,  8.,  7., 20., 25., 42., 33., 50., 62., 76.,
#        97., 97., 75., 62., 80., 57., 58., 47., 36., 16., 17., 13.,  7.,
#         4.,  1.,  0.,  2.])

# %%
limites[1]
# Out:
# array([-2.57994214, -2.40710933, -2.23427653, -2.06144372, -1.88861091,
#        -1.7157781 , -1.5429453 , -1.37011249, -1.19727968, -1.02444688,
#        -0.85161407, -0.67878126, -0.50594845, -0.33311565, -0.16028284,
#         0.01254997,  0.18538277,  0.35821558,  0.53104839,  0.70388119,
#         0.876714  ,  1.04954681,  1.22237962,  1.39521242,  1.56804523,
#         1.74087804,  1.91371084,  2.08654365,  2.25937646,  2.43220927,
#         2.60504207])

# %% [markdown]
# ### Boxplots
#
# Los diagramas de caja eran esos diagramas en los que resumíamos las medidas de posición y añadíamos una posible formar de obtener valores anómalos, extremos o outliers. En forma de diagrama:

# %% [markdown]
# ```text
#      Q1-1.5IQR   Q1  mediana  Q3   Q3+1.5IQR
#                   |-----:-----|
#   o      |--------|     :     |--------|    o  o
#                   |-----:-----|
# flier             <----------->            fliers/outlier
#                        IQR
#
# ```

# %% [markdown]
# Donde IQR es el rango intercuartilico (la diferencia entre el valor de Q3 o tercer cuartil o percentil-75 y el valor de Q1 o primer cuartil, o percentil-25)

# %% [markdown]
# En matplotlib:

# %%
plt. boxplot(data, whis = 1.5);

# %% [markdown]
# En el caso de matplotlib empleamos por defecto diagramas de caja verticales. Pero podemos cambiarlo:

# %%
plt.boxplot(data, vert=False);

# %% [markdown]
# Y podemos mostrar varios juntos:

# %%
plt. boxplot([x1,x2,x3],vert=False);
